# %%
import requests

# %%
page = requests.get("https://www.google.com")
type(page)
# Out:
# requests.models.Response

# %%
# 응답의 내용 출력하기(HTML 코드)
page.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="7niM92vjNW9KCJpGPztXjA==">(function(){window.google={kEI:\'pDU5YoXpPM7M-Qat86vQCQ\',kEXPI:\'0,1302536,56873,6058,207,2415,2389,2316,383,246,5,1354,4013,1238,1122515,1197718,704,17,380052,16114,17444,11240,17572,4859,1361,9290,3026,2818,14765,4020,978,13228,3847,4192,6431,22740,2855,2226,887,707,1278,2742,149,1943,6297,4120,2023,1733,43,521,14670,605,2622,2845,7,17450,16321,1850,2614,13142,3,346,230,6460,148,13975,4,1528,656,1648,6462,577,25073,2658,7356,31,13628,4437,9358,7428,652,5172,2533,4094,17,4035,3,3541,1,16807,38,25309,2,14022,1931,4318,1271,743,5853,10463,1160,5679,1021,2380,2719,18233,9,2,6,5601,2172,4567,6259,6723,16695,830,422,4606,2,6,1221,14968,1538,2794,19,6071,1394,445,2,2,1,6394,565,6127
# ...
